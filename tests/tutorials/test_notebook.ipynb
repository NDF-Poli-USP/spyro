# %% [markdown]
# # Simple test notebook

# %%
# Test basic imports
import spyro
import numpy as np
print("Imports successful")

# %%
# Test basic functionality
x = np.array([1, 2, 3])
print(f"Array: {x}")
